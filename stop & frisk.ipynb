# %%
import pandas as pd
df = pd.read_excel("sqf_2023.xlsx")
# %matplotlib inline
#This data is from 2023 NYC Open Data found here: https://www.nyc.gov/site/nypd/stats/reports-analysis/stopfrisk.page

# %%
df.head()
# Out:
#    STOP_ID STOP_FRISK_DATE STOP_FRISK_TIME  YEAR2   MONTH2    DAY2  \
# 0        1      2023-01-01        00:44:00   2023  January  Sunday
# 1        2      2023-01-01        00:49:00   2023  January  Sunday
# 2        3      2023-01-01        05:31:00   2023  January  Sunday
# 3        4      2023-01-01        04:59:00   2023  January  Sunday
# 4        5      2023-01-01        05:21:00   2023  January  Sunday
#
#         STOP_WAS_INITIATED RECORD_STATUS_CODE ISSUING_OFFICER_RANK  \
# 0       Based on Radio Run                APP                  POM
# 1  Based on Self Initiated                APP                  POM
# 2       Based on Radio Run                APP                  POM
# 3  Based on Self Initiated                APP                  POM
# 4  Based on Self Initiated                APP                  POF
#
#    ISSUING_OFFICER_COMMAND_CODE  ... SUSPECT_OTHER_DESCRIPTION  \
# 0                           804  ...    BLUE HOODIE BLUE JEANS
# ...

# %%
df.tail()
# Out:
#        STOP_ID STOP_FRISK_DATE STOP_FRISK_TIME  YEAR2    MONTH2    DAY2  \
# 16966    16967      2023-12-31        07:10:00   2023  December  Sunday
# 16967    16968      2023-12-31        07:10:00   2023  December  Sunday
# 16968    16969      2023-12-31        07:10:00   2023  December  Sunday
# 16969    16970      2023-12-31        00:42:00   2023  December  Sunday
# 16970    16971      2023-12-31        21:44:00   2023  December  Sunday
#
#           STOP_WAS_INITIATED RECORD_STATUS_CODE ISSUING_OFFICER_RANK  \
# 16966  Based on C/W on Scene                APP                   PO
# 16967  Based on C/W on Scene                APP                   PO
# 16968  Based on C/W on Scene                APP                   PO
# 16969  Based on C/W on Scene                APP                   PO
# 16970     Based on Radio Run                APP                   PO
#
#        ISSUING_OFFICER_COMMAND_CODE  ...  \
# 16966                           114  ...
# ...

# %%
#I'm removing extra columns from this dataset
df_clean = df[['STOP_FRISK_DATE', 'STOP_LOCATION_PRECINCT', 'SUSPECTED_CRIME_DESCRIPTION', 'WEAPON_FOUND_FLAG', 'SUSPECT_REPORTED_AGE', 'SUSPECT_SEX','SUSPECT_RACE_DESCRIPTION']]

# %%
df_clean.head(10)
# Out:
#   STOP_FRISK_DATE  STOP_LOCATION_PRECINCT SUSPECTED_CRIME_DESCRIPTION  \
# 0      2023-01-01                       5                    MENACING
# 1      2023-01-01                      69                         CPW
# 2      2023-01-01                      83                         CPW
# 3      2023-01-01                     113                         CPW
# 4      2023-01-01                      46                         CPW
# 5      2023-01-01                       6                     ASSAULT
# 6      2023-01-01                      23                         CPW
# 7      2023-01-02                      25                    MENACING
# 8      2023-01-02                      68          GRAND LARCENY AUTO
# 9      2023-01-01                      20                         CPW
#
#   WEAPON_FOUND_FLAG SUSPECT_REPORTED_AGE SUSPECT_SEX SUSPECT_RACE_DESCRIPTION
# 0                 N                   32        MALE                    BLACK
# ...

# %%
df_clean['STOP_LOCATION_PRECINCT']
# Out:
# 0          5
# 1         69
# 2         83
# 3        113
# 4         46
#         ...
# 16966    114
# 16967    114
# 16968    114
# 16969    104
# 16970     81
# Name: STOP_LOCATION_PRECINCT, Length: 16971, dtype: int64

# %%
type(df['STOP_LOCATION_PRECINCT'][0])
# Out:
# numpy.int64

# %%
df_precinct = df_clean['STOP_LOCATION_PRECINCT'].value_counts()

# %%
df_precinct
# Out:
# STOP_LOCATION_PRECINCT
# 46     1518
# 48     1110
# 40      754
# 44      732
# 75      540
#        ...
# 10       75
# 5        73
# 17       71
# 111      47
# 22       30
# Name: count, Length: 77, dtype: int64

# %%
df_precinct.sort_values(ascending=False).head(8)
# Out:
# STOP_LOCATION_PRECINCT
# 46    1518
# 48    1110
# 40     754
# 44     732
# 75     540
# 43     516
# 42     509
# 52     469
# Name: count, dtype: int64

# %%
df_precinct.sort_values(ascending=False).tail()
# Out:
# STOP_LOCATION_PRECINCT
# 10     75
# 5      73
# 17     71
# 111    47
# 22     30
# Name: count, dtype: int64

# %%
df_precinct.to_csv('SF_precinct', index=True)

# %%
df_precinct
# Out:
# STOP_LOCATION_PRECINCT
# 46     1518
# 48     1110
# 40      754
# 44      732
# 75      540
#        ...
# 10       75
# 5        73
# 17       71
# 111      47
# 22       30
# Name: count, Length: 77, dtype: int64

# %%
#We are making sure that the dataset is accurate by printing all the stops in Precinct 22 and seeing if it matches the value_counts
df_clean[df_clean['STOP_LOCATION_PRECINCT'] == 22]
# Out:
#       STOP_FRISK_DATE  STOP_LOCATION_PRECINCT    SUSPECTED_CRIME_DESCRIPTION  \
# 1541       2023-02-08                      22                            CPW
# 2328       2023-02-19                      22                          OTHER
# 2329       2023-02-19                      22                  GRAND LARCENY
# 2330       2023-02-20                      22                            CPW
# 2914       2023-02-20                      22                            CPW
# 3642       2023-03-24                      22              FORCIBLE TOUCHING
# 4610       2023-04-13                      22  UNAUTHORIZED USE OF A VEHICLE
# 4611       2023-04-13                      22  UNAUTHORIZED USE OF A VEHICLE
# 5670       2023-05-05                      22                        ASSAULT
# 6130       2023-05-12                      22                        ASSAULT
# 7074       2023-05-31                      22                  PETIT LARCENY
# ...

# %%
#Seeing how many people were stop and frisked in each racial group
df_clean['SUSPECT_RACE_DESCRIPTION'].value_counts()
# Out:
# SUSPECT_RACE_DESCRIPTION
# BLACK                             9939
# WHITE HISPANIC                    3447
# BLACK HISPANIC                    1719
# WHITE                              942
# (null)                             472
# ASIAN / PACIFIC ISLANDER           288
# MIDDLE EASTERN/SOUTHWEST ASIAN     142
# AMERICAN INDIAN/ALASKAN NATIVE      22
# Name: count, dtype: int64

# %%
df_2 = df_clean[['STOP_LOCATION_PRECINCT','SUSPECT_RACE_DESCRIPTION']]

# %%
df_race = df_2.groupby(['STOP_LOCATION_PRECINCT','SUSPECT_RACE_DESCRIPTION']).value_counts().reset_index(name= 'Count')

# %%
df_race.head()
# Out:
#    STOP_LOCATION_PRECINCT SUSPECT_RACE_DESCRIPTION  Count
# 0                       1                   (null)      1
# 1                       1                    BLACK     52
# 2                       1           BLACK HISPANIC      6
# 3                       1                    WHITE     17
# 4                       1           WHITE HISPANIC     10

# %%
df_race.to_csv('sf_race', index=True)

# %%
df.shape[0]
# Out:
# 16971
